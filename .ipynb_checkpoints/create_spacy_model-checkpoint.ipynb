# %%
import spacy
import random

TRAIN_DATA = [('as vendas de hoje\r', {'entities': [(13, 17, '1')]}), ('as vendas de atual\r', {'entities': [(13, 18, '1')]}), ('as vendas de ontem\r', {'entities': [(13, 18, '-1')]}), ('as vendas de amanha\r', {'entities': [(13, 19, '+1')]}), ('as vendas da semana\r', {'entities': [(13, 19, '7')]}), ('as vendas da semana atual\r', {'entities': [(20, 25, '1'), (13, 20, '7')]}), ('as vendas da semana passada\r', {'entities': [(13, 19, '7'), (20, 27, '-1')]}), ('as vendas da semana anterior\r', {'entities': [(13, 20, '7'), (20, 28, '-1')]}), ('as vendas da semana proxima\r', {'entities': [(13, 20, '7'), (20, 27, '+1')]}), ('as vendas da semana proximo\r', {'entities': [(13, 20, '7'), (20, 27, '+1')]}), ('as vendas da semana que vem\r', {'entities': [(13, 20, '7'), (20, 27, '+1')]}), ('as vendas da passada semana\r', {'entities': [(21, 27, '7'), (13, 21, '-1')]}), ('as vendas da anterior semana \r', {'entities': [(13, 22, '-1'), (22, 28, '7')]}), ('as vendas da proxima semana\r', {'entities': [(13, 21, '+1'), (21, 27, '7')]}), ('as vendas da proximo semana\r', {'entities': [(13, 21, '+1'), (21, 27, '7')]}), ('as vendas da que vem semana\r', {'entities': [(21, 27, '7'), (13, 20, '+1')]}), ('as vendas da semanas passadas\r', {'entities': [(13, 21, '7'), (21, 29, '-2')]}), ('as vendas da semanas anteriores\r', {'entities': [(13, 21, '7'), (21, 31, '-2')]}), ('as vendas da semanas proximas\r', {'entities': [(13, 21, '7'), (21, 29, '+2')]}), ('as vendas da semanas proximos\r', {'entities': [(13, 20, '7'), (21, 29, '+2')]}), ('as vendas da semanas que vierem\r', {'entities': [(13, 21, '7'), (21, 31, '+2')]}), ('as vendas da passadas semanas\r', {'entities': [(13, 22, '-2'), (22, 29, '7')]}), ('as vendas da anteriores semanas\r', {'entities': [(24, 31, '7'), (13, 23, '-2')]}), ('as vendas da proximas semanas\r', {'entities': [(13, 22, '+2'), (22, 29, '7')]}), ('as vendas da proximos semanas\r', {'entities': [(13, 22, '+2'), (22, 29, '7')]}), ('as vendas da que vem semanas\r', {'entities': [(21, 28, '7'), (13, 20, '+2')]}), ('as vendas da que vierem semanas', {'entities': [(24, 31, '7'), (13, 23, '+2')]}),('as vendas do mes\r', {'entities': [(13, 16, '30')]}), ('as vendas do mes atual\r', {'entities': [(17, 22, '1'), (13, 17, '30')]}), ('as vendas do mes passado\r', {'entities': [(17, 24, '-1'), (13, 16, '30')]}), ('as vendas do mes anterior\r', {'entities': [(13, 17, '30'), (17, 25, '-1')]}), ('as vendas do mes proximo\r', {'entities': [(13, 17, '30'), (17, 24, '+1')]}), ('as vendas do mes proxima\r', {'entities': [(13, 17, '30'), (17, 24, '+1')]}), ('as vendas do mes que vem\r', {'entities': [(13, 17, '30'), (17, 24, '+1')]}), ('as vendas do passado mes\r', {'entities': [(21, 24, '30'), (13, 21, '-1')]}), ('as vendas do anterior mes\r', {'entities': [(22, 25, '30'), (13, 22, '-1')]}), ('as vendas do proximo mes\r', {'entities': [(21, 24, '30'), (13, 21, '+1')]}), ('as vendas do proxima mes\r', {'entities': [(13, 21, '+1'), (21, 24, '30')]}), ('as vendas do que vem mes\r', {'entities': [(21, 24, '30'), (13, 20, '+1')]}), ('as vendas do meses passados\r', {'entities': [(13, 18, '30'), (19, 27, '-2')]}), ('as vendas do meses anteriores\r', {'entities': [(13, 19, '30'), (19, 29, '-2')]}), ('as vendas do meses proximos\r', {'entities': [(13, 19, '30'), (19, 27, '+2')]}), ('as vendas do meses proximas\r', {'entities': [(19, 27, '+2'), (13, 19, '30')]}), ('as vendas do meses que vierem\r', {'entities': [(13, 19, '30'), (19, 29, '+2')]}), ('as vendas do passados meses\r', {'entities': [(22, 27, '30'), (13, 21, '+2')]}), ('as vendas do anteriores meses\r', {'entities': [(13, 24, '-2'), (24, 29, '30')]}), ('as vendas do proximos meses\r', {'entities': [(22, 27, '30'), (13, 22, '+2')]}), ('as vendas do proximas meses\r', {'entities': [(13, 22, '+2'), (22, 27, '30')]}), ('as vendas do meses que vierem', {'entities': [(13, 19, '30'), (19, 29, '+2')]}),('as vendas do ano\r', {'entities': [(13, 16, '365')]}), ('as vendas do ano atual\n', {'entities': [(17, 22, '1'), (13, 17, '365')]}), ('as vendas do ano passado\r', {'entities': [(13, 16, '365'), (17, 24, '-1')]}), ('as vendas do ano anterior\r', {'entities': [(13, 17, '365'), (17, 25, '-1')]}), ('as vendas do ano proximo\r', {'entities': [(13, 16, '365'), (17, 24, '+1')]}), ('as vendas do ano proxima\r', {'entities': [(13, 17, '365'), (17, 24, '+1')]}), ('as vendas do ano que vem\r', {'entities': [(13, 17, '365'), (17, 24, '+1')]}), ('as vendas do passado ano\r', {'entities': [(13, 21, '-1'), (21, 24, '365')]}), ('as vendas do anterior ano\r', {'entities': [(13, 22, '-1'), (22, 25, '365')]}), ('as vendas do proximo ano\r', {'entities': [(13, 21, '+1'), (21, 24, '365')]}), ('as vendas do proxima ano\r', {'entities': [(13, 21, '+1'), (21, 24, '365')]}), ('as vendas do que vem ano\r', {'entities': [(21, 24, '365'), (13, 20, '+1')]}), ('as vendas do anos passados\r', {'entities': [(13, 18, '365'), (18, 26, '-2')]}), ('as vendas do anos anteriores\r', {'entities': [(13, 18, '365'), (18, 28, '-2')]}), ('as vendas do anos proximos\r', {'entities': [(13, 18, '365'), (18, 26, '+2')]}), ('as vendas do anos proximas\r', {'entities': [(13, 18, '365'), (18, 26, '+2')]}), ('as vendas do anos que vierem\r', {'entities': [(13, 18, '365'), (18, 28, '+2')]}), ('as vendas do passados anos\r', {'entities': [(13, 22, '-2'), (22, 26, '365')]}), ('as vendas do anteriores anos\r', {'entities': [(24, 28, '365'), (13, 24, '-2')]}), ('as vendas do proximos anos\r', {'entities': [(22, 26, '365'), (13, 22, '+2')]}), ('as vendas do proximas anos \r', {'entities': [(13, 22, '+2'), (22, 26, '365')]}), ('as vendas do que vem anos', {'entities': [(21, 25, '365'), (13, 20, '+1')]}),('as vendas da trimestre\r', {'entities': [(13, 22, '90')]}), ('as vendas da trimestre atual\r', {'entities': [(23, 28, '1'), (13, 23, '90')]}), ('as vendas da trimestre passada\r', {'entities': [(13, 23, '90'), (23, 30, '-1')]}), ('as vendas da trimestre anterior\r', {'entities': [(13, 23, '90'), (23, 31, '-1')]}), ('as vendas da trimestre proxima\r', {'entities': [(13, 23, '90'), (23, 30, '+1')]}), ('as vendas da trimestre proximo\r', {'entities': [(13, 23, '90'), (23, 30, '+1')]}), ('as vendas da trimestre que vem\r', {'entities': [(13, 23, '90'), (23, 30, '+1')]}), ('as vendas da passada trimestre\r', {'entities': [(21, 30, '90'), (13, 21, '-1')]}), ('as vendas da anterior trimestre \r', {'entities': [(22, 31, '90'), (13, 22, '-1')]}), ('as vendas da proxima trimestre\r', {'entities': [(21, 30, '90'), (13, 21, '+1')]}), ('as vendas da proximo trimestre\r', {'entities': [(21, 30, '90'), (13, 21, '+1')]}), ('as vendas da que vem trimestre\r', {'entities': [(21, 30, '90'), (13, 20, '+1')]}), ('as vendas da trimestres passadas\r', {'entities': [(13, 24, '90')]}), ('as vendas da trimestres anteriores\r', {'entities': [(13, 23, '90'), (24, 34, '-2')]}), ('as vendas da trimestres proximas\r', {'entities': [(13, 23, '90'), (24, 32, '+2')]}), ('as vendas da trimestres proximos\r', {'entities': [(13, 24, '90'), (24, 32, '+2')]}), ('as vendas da trimestres que vierem\r', {'entities': [(13, 24, '90'), (24, 34, '+2')]}), ('as vendas da passadas trimestres\r', {'entities': [(13, 22, '-2'), (22, 32, '90')]}), ('as vendas da anteriores trimestres\r', {'entities': [(13, 24, '-2'), (24, 34, '90')]}), ('as vendas da proximas trimestres\r', {'entities': [(13, 22, '+2'), (22, 32, '90')]}), ('as vendas da proximos trimestres\r', {'entities': [(13, 22, '+2'), (22, 32, '90')]}), ('as vendas da que vem trimestres\r', {'entities': [(21, 31, '90'), (13, 20, '+1')]}), ('as vendas da que vierem trimestres', {'entities': [(24, 34, '90'), (13, 23, '+2')]})]

def train_spacy(data,iterations):
    TRAIN_DATA = data
    nlp = spacy.blank('pt') 
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
       
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
            ner.add_label(ent[2])

            other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print("Statring iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                nlp.update(
                    [text], 
                    [annotations], 
                    drop=0.2, 
                    sgd=optimizer,  
                    losses=losses)
            print(losses)
    return nlp


prdnlp = train_spacy(TRAIN_DATA, 100)


print('Saving model')
modelfile = 'model'
prdnlp.to_disk(modelfile)

test_text = 'model01'
doc = prdnlp(test_text)
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Statring iteration 0
# {'ner': 161.8868337199936}
# Statring iteration 1
# {'ner': 107.25444161692432}
# Statring iteration 2
# {'ner': 72.34355564156056}
# Statring iteration 3
# {'ner': 55.20795933382881}
# Statring iteration 4
# {'ner': 35.995295375472416}
# Statring iteration 5
# {'ner': 46.291776891688976}
# Statring iteration 6
# {'ner': 21.26251232383475}
# Statring iteration 7
# {'ner': 6.717649011644568}
# Statring iteration 8
# {'ner': 7.778549282556313}
# Statring iteration 9
# {'ner': 11.578968269625332}
# Statring iteration 10
# {'ner': 14.359383771102879}
# Statring iteration 11
# {'ner': 15.653564499199078}
# Statring iteration 12
# {'ner': 22.073762519404035}
# Statring iteration 13
# {'ner': 16.497629159592357}
# Statring iteration 14
# {'ner': 12.042384514864516}
# Statring iteration 15
# {'ner': 38.63111065626457}
# Statring iteration 16
# {'ner': 24.32035453341136}
# Statring iteration 17
# {'ner': 10.869524655888856}
# Statring iteration 18
# ...

# %%
import spacy
nlp = spacy.load('model')
text = 'as vendas o ano passado'
doc = nlp(text)
print("Entidades : ", [(ent.text, ent.label_) for ent in doc.ents])
print("Tokens    :", [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Entidades :  [('ano', '365'), ('passado', '-1')]
# Tokens    : [('as', '', 2), ('vendas', '', 2), ('o', '', 2), ('ano', '365', 3), ('passado', '-1', 3)]
